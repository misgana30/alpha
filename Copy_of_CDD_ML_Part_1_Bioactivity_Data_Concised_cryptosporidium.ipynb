# %% [markdown]
# <a href="https://colab.research.google.com/github/misgana30/alpha/blob/master/Copy_of_CDD_ML_Part_1_Bioactivity_Data_Concised_cryptosporidium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] impdh of crypto (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading https://files.pythonhosted.org/packages/2e/48/0db29040c92726fcc6f99a5bc89e0ea8cf5a9d84753ebaaf53108792da2a/chembl-webresource-client-0.10.2.tar.gz (51kB)
#      |████████████████████████████████| 61kB 4.0MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (2.23.0)
# Collecting requests-cache>=0.4.7
#   Downloading https://files.pythonhosted.org/packages/7f/55/9b1c40eb83c16d8fc79c5f6c2ffade04208b080670fbfc35e0a5effb5a92/requests_cache-0.5.2-py2.py3-none-any.whl
# Requirement already satisfied: easydict in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Building wheels for collected packages: chembl-webresource-client
#   Building wheel for chembl-webresource-client (setup.py) ... done
#   Created wheel for chembl-webresource-client: filename=chembl_webresource_client-0.10.2-cp36-none-any.whl size=55663 sha256=3a1f2167c1baeef3565cd416cf815beae19388f5aacfd04dfd1f539e8d2aa894
#   Stored in directory: /root/.cache/pip/wheels/e6/96/19/3f042bfda7c669bfe24c8278477f57b0fbbf3e488b4c09e3a8
# Successfully built chembl-webresource-client
# Installing collected packages: requests-cache, chembl-webresource-client
# Successfully installed chembl-webresource-client-0.10.2 requests-cache-0.5.2

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('cryptosporidium')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  ...  tax_id
# 0                                                  []  ...    5806
# 1                                                  []  ...    5807
# 2                                                  []  ...  237895
# 3   [{'xref_id': 'Q7YY76', 'xref_name': None, 'xre...  ...    5807
# 4   [{'xref_id': 'Q7YY07', 'xref_name': None, 'xre...  ...    5807
# 5   [{'xref_id': 'Q5CGA3', 'xref_name': None, 'xre...  ...  237895
# 6   [{'xref_id': 'Q8T6T2', 'xref_name': None, 'xre...  ...    5807
# 7                                                  []  ...    5807
# 8                                                  []  ...    5807
# 9                                                  []  ...  353152
# 10                                                 []  ...  353152
# 11                                                 []  ...    5807
# 12                                                 []  ...  353152
# 13                                                 []  ...  353152
# 14                                                 []  ...    5807
#
# [15 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL6145'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     activity_comment  activity_id  ... upper_value   value
# 0               None      2646090  ...        None   0.009
# 1               None      2646091  ...        None   0.009
# 2               None      2646092  ...        None   0.013
# 3               None      2646093  ...        None   0.018
# 4               None      2646094  ...        None    0.02
# ..               ...          ...  ...         ...     ...
# 439             None     15122617  ...        None  5000.0
# 440             None     15122618  ...        None  5000.0
# 441             None     15122619  ...        None    49.0
# 442             None     15122620  ...        None     0.6
# 443             None     15122621  ...        None     0.5
#
# [444 rows x 43 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('IMDH_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     activity_comment  activity_id  ... upper_value   value
# 0               None      2646090  ...        None   0.009
# 1               None      2646091  ...        None   0.009
# 2               None      2646092  ...        None   0.013
# 3               None      2646093  ...        None   0.018
# 4               None      2646094  ...        None    0.02
# ..               ...          ...  ...         ...     ...
# 439             None     15122617  ...        None  5000.0
# 440             None     15122618  ...        None  5000.0
# 441             None     15122619  ...        None    49.0
# 442             None     15122620  ...        None     0.6
# 443             None     15122621  ...        None     0.5
#
# [379 rows x 43 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 231

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     activity_comment  activity_id  ... upper_value   value
# 0               None      2646090  ...        None   0.009
# 1               None      2646091  ...        None   0.009
# 2               None      2646092  ...        None   0.013
# 3               None      2646093  ...        None   0.018
# 4               None      2646094  ...        None    0.02
# ..               ...          ...  ...         ...     ...
# 428             None     15122606  ...        None  5000.0
# 432             None     15122610  ...        None   190.0
# 433             None     15122611  ...        None     9.0
# 436             None     15122614  ...        None   330.0
# 441             None     15122619  ...        None    49.0
#
# [231 rows x 43 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL554067  ...            9.0
# 1         CHEMBL549610  ...            9.0
# 2         CHEMBL549612  ...           13.0
# 3         CHEMBL563640  ...           18.0
# 4         CHEMBL562828  ...           20.0
# ..                 ...  ...            ...
# 428      CHEMBL3329560  ...         5000.0
# 432      CHEMBL3329561  ...          190.0
# 433      CHEMBL3329562  ...            9.0
# 436      CHEMBL3329563  ...          330.0
# 441      CHEMBL3329564  ...           49.0
#
# [231 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('impdh_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('impdh_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id  ...         class
# 0         CHEMBL554067  ...        active
# 1         CHEMBL549610  ...        active
# 2         CHEMBL549612  ...        active
# 3         CHEMBL563640  ...        active
# 4         CHEMBL562828  ...        active
# ..                 ...  ...           ...
# 226      CHEMBL3329560  ...  intermediate
# 227      CHEMBL3329561  ...        active
# 228      CHEMBL3329562  ...        active
# 229      CHEMBL3329563  ...        active
# 230      CHEMBL3329564  ...        active
#
# [231 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('impdh_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: IMDH_data_raw.csv (deflated 94%)
#   adding: impdh_02_bioactivity_data_preprocessed.csv (deflated 83%)
#   adding: impdh_03_bioactivity_data_curated.csv (deflated 85%)

# %%
! ls -l
# Out:
# total 324
# -rw-r--r-- 1 root root  21941 Jan 10 15:19 acetylcholinesterase.zip
# -rw-r--r-- 1 root root 264176 Jan 10 15:17 IMDH_data_raw.csv
# -rw-r--r-- 1 root root  15375 Jan 10 15:18 impdh_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  17466 Jan 10 15:19 impdh_03_bioactivity_data_curated.csv
# drwxr-xr-x 1 root root   4096 Jan  6 18:10 sample_data

# %% [markdown]
# ---
